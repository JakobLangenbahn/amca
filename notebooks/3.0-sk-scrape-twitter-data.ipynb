# %% [markdown]
# Politiker-Tweets Scrapen und einen Corpus bauen.

# %%
# importing libraries and packages
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %% [markdown]
# CDU Tweets

# %%
#Ralph Brinkhaus 
# Creating list to append tweet data to
tweets_listCDU1 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:rbrinkhaus').get_items()):
    if i>1000000:
        break
    tweets_listCDU1.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfCDU1 = pd.DataFrame(tweets_listCDU1, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfCDU1.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2021-12-24 09:06:37+00:00  1474305500472922113
# 1 2021-12-17 13:41:57+00:00  1471838074413924356
# 2 2021-12-15 12:34:54+00:00  1471096426381942791
# 3 2021-12-15 11:58:36+00:00  1471087291913449472
# 4 2021-12-15 11:58:35+00:00  1471087286301380616
#
#                                                 Text    Username  \
# 0  Ich wünsche Ihnen ein frohes und gesegnetes We...  rbrinkhaus
# 1  Herzlichen Glückwunsch @_FriedrichMerz. Alles ...  rbrinkhaus
# 2  @dieLinke Die Rede in voller Länge gibt es in ...  rbrinkhaus
# 3  Eine Demokratie braucht eine starke #Oppositio...  rbrinkhaus
# 4  Eine gefährliche Mischung sehen wir in der #Mi...  rbrinkhaus
#
#       Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Ralph Brinkhaus           24              5          82
# 1  Ralph Brinkhaus          133             22         611
# 2  Ralph Brinkhaus            7              2          13
# ...

# %%
#Hermann Gröhe  
# Creating list to append tweet data to
tweets_listCDU2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:groehe').get_items()):
    if i>1000000:
        break
    tweets_listCDU2.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfCDU2 = pd.DataFrame(tweets_listCDU2, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfCDU2.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-01-04 17:04:02+00:00  1478411915693076483
# 1 2022-01-01 17:48:01+00:00  1477335818306043911
# 2 2021-12-29 21:40:11+00:00  1476307083201060873
# 3 2021-12-29 21:18:55+00:00  1476301730585399304
# 4 2021-12-28 12:54:32+00:00  1475812410351132677
#
#                                                 Text Username   Twitter_Name  \
# 0  Die Menschen über 60 Jahre in Nordrhein-Westfa...   groehe  Hermann Gröhe
# 1                            https://t.co/mYQzzhG52U   groehe  Hermann Gröhe
# 2  Schulze stimmte im Kabinett der damaligen Fina...   groehe  Hermann Gröhe
# 3  Einfach nur peinlich: SPD-Ministerin Schulze w...   groehe  Hermann Gröhe
# 4  Die Nachbarn bedrohend - die Unterdrückung im ...   groehe  Hermann Gröhe
#
#    Reply_Count  Retweet_Count  Like_Count
# 0            8              2          48
# 1            1              0          28
# 2            4              7          75
# ...

# %%
#Nadine Schön 
# Creating list to append tweet data to
tweets_listCDU3 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:NadineSchoen').get_items()):
    if i>1000000:
        break
    tweets_listCDU3.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfCDU3 = pd.DataFrame(tweets_listCDU3, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfCDU3.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2021-12-22 23:31:34+00:00  1473798397882687501
# 1 2021-12-17 13:34:22+00:00  1471836167595335681
# 2 2021-12-11 14:58:48+00:00  1469683090855505921
# 3 2021-12-10 23:02:37+00:00  1469442455728709638
# 4 2021-12-02 19:07:58+00:00  1466484303844552709
#
#                                                 Text      Username  \
# 0  Was unsere Feuerwehr das ganze Jahr über leist...  NadineSchoen
# 1  Herzlichen Glückwunsch an @_FriedrichMerz und ...  NadineSchoen
# 2  @MIT_bund @gitta_connemann Herzlichen Glückwun...  NadineSchoen
# 3  @superrrnetwork @larsklingbeil @KuehniKev @Esk...  NadineSchoen
# 4                          🌹 https://t.co/LqlHw7vW62  NadineSchoen
#
#    Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Nadine Schön            0              3          33
# 1  Nadine Schön            8              2         131
# 2  Nadine Schön            0              0           7
# ...

# %%
#Norbert Röttgen 
# Creating list to append tweet data to
tweets_listCDU4 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:n_roettgen').get_items()):
    if i>1000000:
        break
    tweets_listCDU4.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfCDU4 = pd.DataFrame(tweets_listCDU4, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfCDU4.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-01-05 15:15:21+00:00  1478746951751450635
# 1 2022-01-05 15:15:21+00:00  1478746950501548035
# 2 2021-12-31 23:15:15+00:00  1477055784160837637
# 3 2021-12-31 17:04:23+00:00  1476962448943071240
# 4 2021-12-30 21:39:35+00:00  1476669317118889985
#
#                                                 Text    Username  \
# 0  Die USA haben die klare Erwartung an Deutschla...  n_roettgen
# 1  Im Fokus von #Baerbock|s USA-Reise wird der Uk...  n_roettgen
# 2  Mit Glücksschwein ins Neue Jahr! Wir freuen un...  n_roettgen
# 3  Mut, Zusammenhalt und Lust auf Zukunft. Das wü...  n_roettgen
# 4  Wir haben das Wissen, die Fähigkeiten &amp; hi...  n_roettgen
#
#       Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Norbert Röttgen            7              6          50
# 1  Norbert Röttgen           10              9          93
# 2  Norbert Röttgen           27              8         501
# ...

# %%
#Peter Altmaier 
# Creating list to append tweet data to
tweets_listCDU5 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:peteraltmaier').get_items()):
    if i>1000000:
        break
    tweets_listCDU5.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfCDU5 = pd.DataFrame(tweets_listCDU5, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfCDU5.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-01-01 10:22:03+00:00  1477223589250228228
# 1 2021-12-31 23:29:21+00:00  1477059330813927429
# 2 2021-12-31 23:28:44+00:00  1477059173368188936
# 3 2021-12-31 23:05:04+00:00  1477053220568670213
# 4 2021-12-31 23:00:53+00:00  1477052168553340930
#
#                                                 Text       Username  \
# 0  @inga_roeger Auch Ihnen ein gutes 2022. \nTwee...  peteraltmaier
# 1                             @BoudyHen Dank U zeer!  peteraltmaier
# 2  @fpleitgenCNN The same to you, Sir! Life is be...  peteraltmaier
# 3           @DreyMahnke Ebenso! Auf ein gutes Neues!  peteraltmaier
# 4  I agree: Böllerverkaufsvefbot didntreslly work...  peteraltmaier
#
#      Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Peter Altmaier           20              1         116
# 1  Peter Altmaier            1              0          40
# 2  Peter Altmaier          337            409        2172
# ...

# %%
#Jens Spahn 
# Creating list to append tweet data to
tweets_listCDU6 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:jensspahn').get_items()):
    if i>1000000:
        break
    tweets_listCDU6.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfCDU6 = pd.DataFrame(tweets_listCDU6, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfCDU6.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2021-12-17 13:33:38+00:00  1471835983033380875
# 1 2021-12-08 17:52:22+00:00  1468639605499084803
# 2 2021-12-08 09:39:04+00:00  1468515462136963074
# 3 2021-12-08 08:23:44+00:00  1468496505296375809
# 4 2021-12-07 15:57:44+00:00  1468248369353175043
#
#                                                 Text   Username Twitter_Name  \
# 0  Herzlichen Glückwunsch @_FriedrichMerz #Christ...  jensspahn   Jens Spahn
# 1  Es war die bisher größte Aufgabe meines Lebens...  jensspahn   Jens Spahn
# 2  Herzlichen Glückwunsch @OlafScholz und gutes G...  jensspahn   Jens Spahn
# 3  Allein am gestrigen Dienstag hat ein Prozent d...  jensspahn   Jens Spahn
# 4  🇪🇺 On my last day in office, I attended the EU...  jensspahn   Jens Spahn
#
#    Reply_Count  Retweet_Count  Like_Count
# 0          162             18         369
# 1          612             82        2852
# 2           98             24         679
# ...

# %%
#Matthias Hauer 
# Creating list to append tweet data to
tweets_listCDU7 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:MatthiasHauer').get_items()):
    if i>1000000:
        break
    tweets_listCDU7.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfCDU7 = pd.DataFrame(tweets_listCDU7, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfCDU7.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-01-05 21:07:54+00:00  1478835672073097217
# 1 2022-01-05 21:06:38+00:00  1478835353188507648
# 2 2022-01-05 20:51:40+00:00  1478831588217610246
# 3 2022-01-05 20:50:30+00:00  1478831293764972547
# 4 2022-01-05 18:00:49+00:00  1478788592654761987
#
#                                                 Text       Username  \
# 0           @Julian81295 @erlen_zeisig Welcher Witz?  MatthiasHauer
# 1  @MGrosseBroemer Gäste von außerhalb sind gern ...  MatthiasHauer
# 2  @erlen_zeisig Besser als ein Sozi - für den mü...  MatthiasHauer
# 3  @ghsa7ne Genau. Er wollte sich wahrscheinlich ...  MatthiasHauer
# 4  Mein Einsatz gegen #Stalking wird gewürdigt. I...  MatthiasHauer
#
#      Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Matthias Hauer            0              0           5
# 1  Matthias Hauer            0              0           1
# 2  Matthias Hauer            1              0          13
# ...

# %% [markdown]
# SPD

# %%
#Lars Klingbeil 
# Creating list to append tweet data to
tweets_listSPD1 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:larsklingbeil').get_items()):
    if i>1000000:
        break
    tweets_listSPD1.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfSPD1 = pd.DataFrame(tweets_listSPD1, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfSPD1.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-01-05 16:06:15+00:00  1478759758626803720
# 1 2022-01-04 10:53:10+00:00  1478318584346644481
# 2 2021-12-31 16:33:03+00:00  1476954566000365575
# 3 2021-12-29 08:16:18+00:00  1476104778543476737
# 4 2021-12-29 07:59:17+00:00  1476100494611435522
#
#                                                 Text       Username  \
# 0                        @josefheynckes Mach Urlaub.  larsklingbeil
# 1  2017 wurde Frank-Walter Steinmeier von SPD &am...  larsklingbeil
# 2                @NowaboFM Guten Rutsch euch beiden!  larsklingbeil
# 3  @RaphaelBrinkert @GordonRepinski @MichaelBroec...  larsklingbeil
# 4  „Ich danke der Academy.“ @GordonRepinski @Mich...  larsklingbeil
#
#         Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Lars Klingbeil 🇪🇺            2              0          27
# 1  Lars Klingbeil 🇪🇺          124             64        1662
# 2  Lars Klingbeil 🇪🇺            3              1          67
# ...

# %%
#Saskia Esken 
# Creating list to append tweet data to
tweets_listSPD2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:EskenSaskia').get_items()):
    if i>1000000:
        break
    tweets_listSPD2.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfSPD2 = pd.DataFrame(tweets_listSPD2, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfSPD2.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-01-05 18:19:56+00:00  1478793401474629642
# 1 2022-01-05 16:57:39+00:00  1478772697370869760
# 2 2022-01-04 12:47:54+00:00  1478347455859208194
# 3 2022-01-04 10:50:55+00:00  1478318016479780866
# 4 2022-01-03 21:34:26+00:00  1478117575125082119
#
#                                                 Text     Username  \
# 0                        @fegebanks Oje, alles Gute!  EskenSaskia
# 1  @GaiaXFakten @_cgraf_ @UlrichKelber @rki_de @s...  EskenSaskia
# 2  @CupcakeLady_ @johannesvogel @hubertus_heil @w...  EskenSaskia
# 3  Es freut mich, dass auch @Die_Gruenen eine zwe...  EskenSaskia
# 4  @lVIicha @ManuelaSchwesig @wanderwitz @Karl_La...  EskenSaskia
#
#    Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Saskia Esken            0              0          10
# 1  Saskia Esken            2              0           2
# 2  Saskia Esken            1              0          29
# ...

# %%
#Hubertus Heil 
# Creating list to append tweet data to
tweets_listSPD3 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:hubertus_heil').get_items()):
    if i>1000000:
        break
    tweets_listSPD3.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfSPD3 = pd.DataFrame(tweets_listSPD3, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfSPD3.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-01-04 10:46:39+00:00  1478316941865541633
# 1 2021-12-27 10:05:31+00:00  1475407486941282307
# 2 2021-12-21 21:05:43+00:00  1473399303590883340
# 3 2021-12-21 11:18:23+00:00  1473251496577974277
# 4 2021-12-17 13:32:47+00:00  1471835769857847300
#
#                                                 Text       Username  \
# 0  Bundespräsident Frank-Walter Steinmeier ist ei...  hubertus_heil
# 1  Interview mit ⁦@NDRinfo⁩ zu Arbeit, Mindestloh...  hubertus_heil
# 2  @FischerSeverin @FranziskaGiffey Glückwunsch, ...  hubertus_heil
# 3  Klug, tatkräftig und zuversichtlich: Das ist d...  hubertus_heil
# 4  Auch eine Oppositionspartei wie die CDU trägt ...  hubertus_heil
#
#     Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Hubertus Heil          866             87        1060
# 1  Hubertus Heil           65             17         153
# 2  Hubertus Heil            1              0           9
# ...

# %%
#Heiko Maas 
# Creating list to append tweet data to
tweets_listSPD4 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:HeikoMaas').get_items()):
    if i>1000000:
        break
    tweets_listSPD4.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfSPD4 = pd.DataFrame(tweets_listSPD4, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfSPD4.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2021-12-15 09:30:59+00:00  1471050140790272005
# 1 2021-12-08 09:43:33+00:00  1468516588412358656
# 2 2021-12-06 09:23:36+00:00  1467786795777671168
# 3 2021-12-06 09:23:36+00:00  1467786794183888897
# 4 2021-12-04 13:08:24+00:00  1467118588981313536
#
#                                                 Text   Username  \
# 0  Herzlichen Glückwunsch zum Geburtstag an unser...  HeikoMaas
# 1  Das Parlament hat gewählt: Der 9. #Bundeskanzl...  HeikoMaas
# 2  Ich freue mich sehr darauf, @OlafScholz am Mit...  HeikoMaas
# 3  .@OlafScholz hat eine großartige Wahl getroffe...  HeikoMaas
# 4  Einen Fortschritt, den wir jetzt gemeinsam mit...  HeikoMaas
#
#     Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Heiko Maas 🇪🇺           26             18         552
# 1  Heiko Maas 🇪🇺           39             30         394
# 2  Heiko Maas 🇪🇺           31             14         491
# ...

# %%
#Martin Schulz 
# Creating list to append tweet data to
tweets_listSPD5 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:MartinSchulz').get_items()):
    if i>1000000:
        break
    tweets_listSPD5.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfSPD5 = pd.DataFrame(tweets_listSPD5, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfSPD5.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2021-12-24 09:02:06+00:00  1474304366484115460
# 1 2021-12-16 08:39:30+00:00  1471399572866056192
# 2 2021-12-09 16:45:40+00:00  1468985209127415812
# 3 2021-12-08 09:24:40+00:00  1468511838086303744
# 4 2021-12-01 13:23:52+00:00  1466035318365294603
#
#                                                 Text      Username  \
# 0  Frohe Weihnachten! Das war sicher erneut ein J...  MartinSchulz
# 1  Kann keiner behaupten, ich hätte es nicht gesa...  MartinSchulz
# 2  Kommen jetzt (endlich) die Vereinigten Staaten...  MartinSchulz
# 3  Wir haben jahrelang dafür gekämpft und jetzt i...  MartinSchulz
# 4  Ich freue mich sehr auf die Panel-Diskussion m...  MartinSchulz
#
#     Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Martin Schulz           17             12         384
# 1  Martin Schulz          301            564       11185
# 2  Martin Schulz            9              7          54
# ...

# %%
#Dr. Karamba Diaby 
# Creating list to append tweet data to
tweets_listSPD6 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:KarambaDiaby').get_items()):
    if i>1000000:
        break
    tweets_listSPD6.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfSPD6 = pd.DataFrame(tweets_listSPD6, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfSPD6.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2021-12-14 15:06:10+00:00  1470772107084718086
# 1 2021-12-08 10:51:57+00:00  1468533805338218496
# 2 2021-12-01 20:41:13+00:00  1466145381142745093
# 3 2021-11-27 11:12:54+00:00  1464552810717007878
# 4 2021-11-25 10:26:43+00:00  1463816411730649088
#
#                                                 Text      Username  \
# 0  In dieser Legislatur darf ich die @spdbt im Au...  KarambaDiaby
# 1  Soeben wurde @OlafScholz zum #Bundeskanzler ge...  KarambaDiaby
# 2  @josefheynckes Starke Botschaften des künftige...  KarambaDiaby
# 3  @SawsanChebli @spdde Herzlichen Dank, liebe @S...  KarambaDiaby
# 4  Wir haben mit dem #Koalitionsvertrag einen gro...  KarambaDiaby
#
#         Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Dr. Karamba Diaby           35             26        1479
# 1  Dr. Karamba Diaby           15             25        1131
# 2  Dr. Karamba Diaby            4              1         163
# ...

# %%
#Prof. Karl Lauterbach 
# Creating list to append tweet data to
tweets_listSPD7 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:Karl_Lauterbach').get_items()):
    if i>1000000:
        break
    tweets_listSPD7.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfSPD7 = pd.DataFrame(tweets_listSPD7, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfSPD7.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-01-05 23:59:20+00:00  1478878815904579585
# 1 2022-01-04 22:50:35+00:00  1478499126769815558
# 2 2022-01-03 17:56:57+00:00  1478062843891175443
# 3 2022-01-03 12:12:24+00:00  1477976134432305152
# 4 2022-01-03 00:43:54+00:00  1477802867339804674
#
#                                                 Text         Username  \
# 0  Viele denken: Omikron verläuft milder, weshalb...  Karl_Lauterbach
# 1  Sehr langer und informativer Thread @jburnmurd...  Karl_Lauterbach
# 2  Ein weiterer wichtiger Grund, mittelschwere od...  Karl_Lauterbach
# 3  Diese Daten zeigen eindrücklich wie stark der ...  Karl_Lauterbach
# 4  Das stimmt und zeigt den Wert der Boosterimpfu...  Karl_Lauterbach
#
#             Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Prof. Karl Lauterbach           30             36         170
# 1  Prof. Karl Lauterbach          568            176        1321
# ...

# %% [markdown]
# Grüne

# %%
#SteffiLemke 
# Creating list to append tweet data to
tweets_listB90G1 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:SteffiLemke').get_items()):
    if i>1000000:
        break
    tweets_listB90G1.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfB90G1 = pd.DataFrame(tweets_listB90G1, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfB90G1.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-01-05 17:21:05+00:00  1478778592368734211
# 1 2022-01-03 20:42:09+00:00  1478104418260336650
# 2 2021-12-20 18:47:23+00:00  1473002106378502150
# 3 2021-12-18 10:24:18+00:00  1472150722552778759
# 4 2021-12-15 21:28:12+00:00  1471230637377998849
#
#                                                 Text     Username  \
# 0  Herzlich willkommen auf Twitter! #BMWSB Twitte...  SteffiLemke
# 1                          👇 https://t.co/WaZh2tmYGH  SteffiLemke
# 2  Mein erster Umweltministerrat ist beendet. Auf...  SteffiLemke
# 3  Natürlicher Klimaschutz, Klimavorsorge, Verbra...  SteffiLemke
# 4  @GruenSprecher @GoeringEckardt @GrueneBundesta...  SteffiLemke
#
#   Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  SteffiLemke            4              1          93
# 1  SteffiLemke           17             11          70
# 2  SteffiLemke           10              5         372
# ...

# %%
#Cem Özdemir 
# Creating list to append tweet data to
tweets_listB90G2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:cem_oezdemir').get_items()):
    if i>1000000:
        break
    tweets_listB90G2.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfB90G2 = pd.DataFrame(tweets_listB90G2, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfB90G2.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-01-05 19:23:52+00:00  1478809490963279875
# 1 2022-01-05 12:55:28+00:00  1478711746361798667
# 2 2022-01-04 09:23:17+00:00  1478295961772433408
# 3 2022-01-03 13:32:26+00:00  1477996277174579201
# 4 2022-01-02 18:59:10+00:00  1477716110946537472
#
#                                                 Text      Username  \
# 0  @katjadoerner Ich erst, Frau Oberbürgermeisterin!  cem_oezdemir
# 1  .@gruenestuttgart greifen nach den Sternen. He...  cem_oezdemir
# 2  @HenrikeRossbach @DjirSarai @SZ @pkr77 Herzlic...  cem_oezdemir
# 3  @julianmieth @bmel Willkommen in einem coolen ...  cem_oezdemir
# 4  Die Schändung von Gräbern in #Iserlohn ist zut...  cem_oezdemir
#
#   Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Cem Özdemir            2              0          43
# 1  Cem Özdemir           17              7         197
# 2  Cem Özdemir            2              2          44
# ...

# %%
#Katrin Göring-Eckardt 
# Creating list to append tweet data to
tweets_listB90G3 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:GoeringEckardt').get_items()):
    if i>1000000:
        break
    tweets_listB90G3.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfB90G3 = pd.DataFrame(tweets_listB90G3, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfB90G3.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-01-05 21:08:36+00:00  1478835847915057153
# 1 2022-01-05 14:48:30+00:00  1478740194840961033
# 2 2022-01-04 08:07:57+00:00  1478277003853938688
# 3 2022-01-02 00:49:37+00:00  1477441917227081731
# 4 2021-12-31 21:59:06+00:00  1477036618808795146
#
#                                                 Text        Username  \
# 0                         @anna_mohn Gute Besserung!  GoeringEckardt
# 1           @DuezenTekkal @fegebanks Gute Besserung!  GoeringEckardt
# 2        Das ist sehr gut so https://t.co/YPdM6UUoek  GoeringEckardt
# 3  Lieber @wanderwitz . Das ist übel. Volle Solid...  GoeringEckardt
# 4                            @Martin_Debes Endlich !  GoeringEckardt
#
#             Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Katrin Göring-Eckardt            0              0           3
# 1  Katrin Göring-Eckardt            0              0           2
# ...

# %%
#Konstantin v. Notz 
# Creating list to append tweet data to
tweets_listB90G4 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:KonstantinNotz').get_items()):
    if i>1000000:
        break
    tweets_listB90G4.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfB90G4 = pd.DataFrame(tweets_listB90G4, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfB90G4.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-01-04 17:11:44+00:00  1478413851049832448
# 1 2022-01-04 14:54:24+00:00  1478379290144219157
# 2 2021-12-27 13:20:04+00:00  1475456448360550402
# 3 2021-12-24 15:42:28+00:00  1474405120016326657
# 4 2021-12-24 12:10:36+00:00  1474351800476180487
#
#                                                 Text        Username  \
# 0  Der #Spiegel - Titel aus der Woche in der ich ...  KonstantinNotz
# 1  Es ist unerträglich,dass die Spitzen von #CDU ...  KonstantinNotz
# 2  Ich denke heute besonders an Guido #Westerwell...  KonstantinNotz
# 3        Frohe Weihnachten 🎄 https://t.co/pNMu75f6nz  KonstantinNotz
# 4  🎄Ich wünsche Euch allen hier, schöne und geseg...  KonstantinNotz
#
#          Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Konstantin v. Notz            8              4          60
# 1  Konstantin v. Notz           76             56         582
# 2  Konstantin v. Notz           19             18         459
# ...

# %%
#Britta Haßelmann 
# Creating list to append tweet data to
tweets_listB90G5 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:BriHasselmann').get_items()):
    if i>1000000:
        break
    tweets_listB90G5.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfB90G5 = pd.DataFrame(tweets_listB90G5, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfB90G5.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-01-05 16:53:04+00:00  1478771542330941443
# 1 2022-01-05 09:06:07+00:00  1478654031790841858
# 2 2022-01-04 12:13:04+00:00  1478338689373806597
# 3 2022-01-04 12:09:34+00:00  1478337810029551622
# 4 2022-01-03 20:22:05+00:00  1478099366305050630
#
#                                                 Text       Username  \
# 0  Wie gut! Alles Gute Dir, lieber @svenlehmann 🌈...  BriHasselmann
# 1  „Einmischung ist die einzige Möglichkeit, real...  BriHasselmann
# 2  Seine starke Stimme für den demokratischen Zus...  BriHasselmann
# 3  Frank-Walter #Steinmeier ist ein sehr guter un...  BriHasselmann
# 4   @nouripour Alles Gute Dir, lieber @nouripour 🌻🌻🌻  BriHasselmann
#
#        Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Britta Haßelmann            3              4         127
# 1  Britta Haßelmann            0              5          59
# 2  Britta Haßelmann           14              2          63
# ...

# %%
#Sven Lehmann 
# Creating list to append tweet data to
tweets_listB90G6 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:svenlehmann').get_items()):
    if i>1000000:
        break
    tweets_listB90G6.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfB90G6 = pd.DataFrame(tweets_listB90G6, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfB90G6.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-01-05 18:54:02+00:00  1478801985235259402
# 1 2022-01-05 18:47:33+00:00  1478800351855890433
# 2 2022-01-05 18:43:52+00:00  1478799425988440064
# 3 2022-01-05 18:41:17+00:00  1478798777217687552
# 4 2022-01-05 18:36:42+00:00  1478797622173388807
#
#                                                 Text     Username  \
# 0                         @dunjahayali ✌️🏳️‍🌈🏳️‍⚧️💯😊  svenlehmann
# 1  @JBrandenburgFDP @BMFSFJ Danke lieber Jens und...  svenlehmann
# 2                                 @herr_emmerich 💚💚🙏  svenlehmann
# 3  @GansGruen Danke liebe Tessa und auf weiterhin...  svenlehmann
# 4          @BriHasselmann Danke liebe Britta! 🏳️‍🌈✌️  svenlehmann
#
#    Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Sven Lehmann            0              0           9
# 1  Sven Lehmann            0              0          10
# 2  Sven Lehmann            0              0           1
# ...

# %%
#Annalena Baerbock 
# Creating list to append tweet data to
tweets_listB90G7 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:ABaerbock').get_items()):
    if i>1000000:
        break
    tweets_listB90G7.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfB90G7 = pd.DataFrame(tweets_listB90G7, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfB90G7.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-01-05 19:20:23+00:00  1478808616794796040
# 1 2022-01-04 18:21:38+00:00  1478431442195693569
# 2 2022-01-04 16:51:54+00:00  1478408861262438403
# 3 2022-01-04 15:56:21+00:00  1478394882838441988
# 4 2021-12-18 15:36:10+00:00  1472229205941358592
#
#                                                 Text   Username  \
# 0  Thank you @SecBlinken for the warm welcome in ...  ABaerbock
# 1  Ich habe mich zu Beginn der französischen EU-R...  ABaerbock
# 2  Ich habe @RauZbigniew telefonisch volle Unters...  ABaerbock
# 3  Vielen Dank, @EUSR_Weber, für den guten Austau...  ABaerbock
# 4  Vielen Dank Maria @by_kalesnikava, Swetlana @T...  ABaerbock
#
#                         Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Außenministerin Annalena Baerbock          102            116        1417
# 1  Außenministerin Annalena Baerbock          100             33         463
# ...

# %% [markdown]
# FDP

# %%
#Christian Lindner 
# Creating list to append tweet data to
tweets_listFDP1 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:c_lindner').get_items()):
    if i>1000000:
        break
    tweets_listFDP1.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfFDP1 = pd.DataFrame(tweets_listFDP1, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfFDP1.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-01-05 15:19:02+00:00  1478747876952002563
# 1 2022-01-04 16:46:02+00:00  1478407383365951499
# 2 2022-01-02 12:10:10+00:00  1477613182567038977
# 3 2022-01-02 10:47:46+00:00  1477592447962296320
# 4 2022-01-01 13:38:02+00:00  1477272908498100227
#
#                                                 Text   Username  \
# 0  Als Finanzminister liegt mir die „fleißige Mit...  c_lindner
# 1  Happy birthday, @derspiegel. 75 Jahre kritisch...  c_lindner
# 2  Es darf nicht in Vergessenheit geraten: Alexej...  c_lindner
# 3  Mein Vorsatz als Finanzminister: Ab 2023 soll ...  c_lindner
# 4  Ab heute übernimmt Deutschland für 2022 die #G...  c_lindner
#
#         Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Christian Lindner          483             28         341
# 1  Christian Lindner          382             16         735
# 2  Christian Lindner         1428            257        3295
# ...

# %%
#Marco Buschmann 
# Creating list to append tweet data to
tweets_listFDP2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:MarcoBuschmann').get_items()):
    if i>1000000:
        break
    tweets_listFDP2.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfFDP2 = pd.DataFrame(tweets_listFDP2, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfFDP2.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-01-04 17:44:31+00:00  1478422102692843520
# 1 2022-01-04 13:37:50+00:00  1478360020551098368
# 2 2022-01-04 13:34:50+00:00  1478359268558618624
# 3 2022-01-04 13:33:37+00:00  1478358959937441793
# 4 2022-01-04 13:32:48+00:00  1478358754613735425
#
#                                                 Text        Username  \
# 0  Alles Gute zum Geburtstag, lieber @derspiegel!...  MarcoBuschmann
# 1  @SabineTheresaK @DirkLaurenz @DIEZEIT Selbst e...  MarcoBuschmann
# 2  @HanfdampfGassen @DIEZEIT Die Legalisierung vo...  MarcoBuschmann
# 3  @ProteusNews @bmj_bund @DIEZEIT Wir haben leid...  MarcoBuschmann
# 4  @jetztkommthorst @DIEZEIT Es war zu jeder Zeit...  MarcoBuschmann
#
#       Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Marco Buschmann          121              5         157
# 1  Marco Buschmann           26              0           3
# 2  Marco Buschmann          183            144         762
# ...

# %%
#Bettina Stark-Watzinger
# Creating list to append tweet data to
tweets_listFDP3 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:Starkwatzinger').get_items()):
    if i>1000000:
        break
    tweets_listFDP3.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfFDP3 = pd.DataFrame(tweets_listFDP3, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfFDP3.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-01-04 08:09:44+00:00  1478277453290299392
# 1 2022-01-03 08:03:57+00:00  1477913610630348800
# 2 2022-01-02 10:10:26+00:00  1477583050418622464
# 3 2022-01-01 12:28:43+00:00  1477255462777090050
# 4 2021-12-30 14:49:30+00:00  1476566116814229509
#
#                                                 Text        Username  \
# 0  Erdgas ist nicht nachhaltig. Aber wenn wir sch...  starkwatzinger
# 1  Heute und morgen startet in einige Bundeslände...  starkwatzinger
# 2  Es gibt tolle Frauen &amp; Männer in unserem L...  starkwatzinger
# 3  @SDullien Das tut mir sehr leid. Mein herzlich...  starkwatzinger
# 4  Kritik unerwünscht - #Pressefreiheit &amp; #Me...  starkwatzinger
#
#               Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Bettina Stark-Watzinger           65             12         163
# 1  Bettina Stark-Watzinger          620             75         747
# ...

# %%
#Alexander Lambsdorff 
# Creating list to append tweet data to
tweets_listFDP4 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:Lambsdorff').get_items()):
    if i>1000000:
        break
    tweets_listFDP4.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfFDP4 = pd.DataFrame(tweets_listFDP4, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfFDP4.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-01-02 09:11:22+00:00  1477568189739454466
# 1 2022-01-01 21:53:47+00:00  1477397670293561356
# 2 2021-12-28 16:20:33+00:00  1475864256944001032
# 3 2021-12-27 09:04:13+00:00  1475392059842482179
# 4 2021-12-27 09:00:58+00:00  1475391244666875907
#
#                                                 Text    Username  \
# 0  Wenn man @dpa_sport glauben darf, war besonder...  Lambsdorff
# 1  Ein starkes Bild - die #Europaflagge weht im A...  Lambsdorff
# 2  Wer einen Funken Anstand, Gespür für historisc...  Lambsdorff
# 3  Russland 🇷🇺 \nhttps://t.co/mnaIxo2xmo\nUkraine...  Lambsdorff
# 4  Weihnachten 🎄 ist vorbei. Twitter heute früh:\...  Lambsdorff
#
#            Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Alexander Lambsdorff            5              0          30
# 1  Alexander Lambsdorff           24             30         367
# 2  Alexander Lambsdorff           39             65         544
# ...

# %%
#Johannes Vogel 
# Creating list to append tweet data to
tweets_listFDP5 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:johannesvogel').get_items()):
    if i>1000000:
        break
    tweets_listFDP5.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfFDP5 = pd.DataFrame(tweets_listFDP5, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfFDP5.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-01-05 15:58:15+00:00  1478757745834795009
# 1 2022-01-05 14:55:59+00:00  1478742076259028994
# 2 2022-01-05 14:09:24+00:00  1478730354978701324
# 3 2022-01-04 14:41:38+00:00  1478376078632701959
# 4 2022-01-04 12:23:18+00:00  1478341264227672065
#
#                                                 Text       Username  \
# 0                                    @philippduerr 💯  johannesvogel
# 1  Einen #Impfschaden könnte vor allem die nächst...  johannesvogel
# 2                      @MEtzold 🤞🏻Dass es so bleibt!  johannesvogel
# 3  Wenn ich einen Wunsch für die nächsten 75 Jahr...  johannesvogel
# 4  Hier zum Ausprobieren! 👇🏻 https://t.co/D9783d2Qi4  johannesvogel
#
#      Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Johannes Vogel            0              0          14
# 1  Johannes Vogel           24             21         304
# 2  Johannes Vogel            0              0           4
# ...

# %%
#Konstantin Kuhle 
# Creating list to append tweet data to
tweets_listFDP6 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:KonstantinKuhle').get_items()):
    if i>1000000:
        break
    tweets_listFDP6.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfFDP6 = pd.DataFrame(tweets_listFDP6, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfFDP6.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-01-05 11:25:53+00:00  1478689201533210626
# 1 2022-01-04 22:38:57+00:00  1478496197614657537
# 2 2022-01-04 12:07:40+00:00  1478337330050129921
# 3 2022-01-04 12:02:41+00:00  1478336075751899140
# 4 2022-01-03 16:05:13+00:00  1478034723964440582
#
#                                                 Text         Username  \
# 0                               @xileffff Pro Woche!  KonstantinKuhle
# 1  @MarkusBlume Keine Sorge, das sparen wir durch...  KonstantinKuhle
# 2  Großartiges Tool! @derspiegel https://t.co/UQ9...  KonstantinKuhle
# 3  Das hier war das @derspiegel-Cover in der Woch...  KonstantinKuhle
# 4  Eine solche CDU kann man sich wirklich auf abs...  KonstantinKuhle
#
#        Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Konstantin Kuhle            3              0          54
# 1  Konstantin Kuhle            6              1          67
# 2  Konstantin Kuhle            7              4          49
# ...

# %%
#Marie-Agnes Strack-Zimmermann 
# Creating list to append tweet data to
tweets_listFDP7 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:MAStrackZi').get_items()):
    if i>1000000:
        break
    tweets_listFDP7.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfFDP7 = pd.DataFrame(tweets_listFDP7, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfFDP7.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2021-12-31 08:25:01+00:00  1476831749397270530
# 1 2021-12-25 13:17:03+00:00  1474730913430921216
# 2 2021-12-25 08:32:00+00:00  1474659176840253440
# 3 2021-12-24 13:16:41+00:00  1474368432451772416
# 4 2021-12-24 12:06:49+00:00  1474350850701242373
#
#                                                 Text    Username  \
# 0  Ich wünsche Ihnen und Euch einen guten Rutsch ...  MAStrackZi
# 1  @Alexand53344730 Ihr Humorverständnis für mein...  MAStrackZi
# 2  Wer unter dem Weihnachtsbaum noch etwas zu les...  MAStrackZi
# 3  @MaxMust01817627 Die Koalition ist seit gerade...  MAStrackZi
# 4  @CarloMasala1 @uedio So kennen und lieben wir ...  MAStrackZi
#
#                     Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Marie-Agnes Strack-Zimmermann           59             18        1280
# 1  Marie-Agnes Strack-Zimmermann            0              0           3
# ...

# %% [markdown]
# Linke

# %%
#Sahra Wagenknecht 
# Creating list to append tweet data to
tweets_listLINKE1 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:SWagenknecht').get_items()):
    if i>1000000:
        break
    tweets_listLINKE1.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfLINKE1 = pd.DataFrame(tweets_listLINKE1, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfLINKE1.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2021-12-31 09:49:26+00:00  1476852991982510105
# 1 2021-12-30 22:54:36+00:00  1476688196180320265
# 2 2021-12-22 19:51:34+00:00  1473743031505494020
# 3 2021-12-21 17:57:53+00:00  1473352035730968581
# 4 2021-12-18 10:34:58+00:00  1472153409784627203
#
#                                                 Text      Username  \
# 0  Interessantes Interview mit Ulrike Guérot: „Wü...  SWagenknecht
# 1  „Faktenchecker“ sind groß in Mode gekommen. Ab...  SWagenknecht
# 2  Im Interview mit der Welt spreche ich über die...  SWagenknecht
# 3  #Impfpflicht ist falsch: Zentralregister &amp;...  SWagenknecht
# 4  Wie kann es sein, dass selbst eine Demonstrati...  SWagenknecht
#
#         Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Sahra Wagenknecht          406           1419        5359
# 1  Sahra Wagenknecht          291           1081        5545
# 2  Sahra Wagenknecht          281            591        3131
# ...

# %%
#Bernd Riexinger 
# Creating list to append tweet data to
tweets_listLINKE2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:b_riexinger').get_items()):
    if i>1000000:
        break
    tweets_listLINKE2.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfLINKE2 = pd.DataFrame(tweets_listLINKE2, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfLINKE2.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-01-05 17:57:26+00:00  1478787739957047297
# 1 2022-01-03 16:10:52+00:00  1478036146852708353
# 2 2022-01-01 13:34:18+00:00  1477271968382607364
# 3 2022-01-01 13:28:18+00:00  1477270458328301568
# 4 2022-01-01 13:06:19+00:00  1477264927421313025
#
#                                                 Text     Username  \
# 0  Der geplante #Bonus für Pflegekräfte  ist eine...  b_riexinger
# 1  Mit #Maassen gibt es einen weiteren gewichtige...  b_riexinger
# 2  Und die Grünen machen dabei auch noch mit. Ver...  b_riexinger
# 3  Gas- und #Atomkraft sollen #Grün sein? Die EU-...  b_riexinger
# 4  Ich wünsche Euch ein frohes und gesundes Jahr ...  b_riexinger
#
#       Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Bernd Riexinger            5              5          48
# 1  Bernd Riexinger           15              7          95
# 2  Bernd Riexinger            2              5          32
# ...

# %%
#Niema Movassat 
# Creating list to append tweet data to
tweets_listLINKE3 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:NiemaMovassat').get_items()):
    if i>1000000:
        break
    tweets_listLINKE3.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfLINKE3 = pd.DataFrame(tweets_listLINKE3, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfLINKE3.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-01-05 21:02:04+00:00  1478834205966708738
# 1 2022-01-05 20:39:51+00:00  1478828612136718339
# 2 2022-01-05 20:38:33+00:00  1478828286600007684
# 3 2022-01-05 20:38:10+00:00  1478828192278450179
# 4 2022-01-05 20:31:38+00:00  1478826546462867458
#
#                                                 Text       Username  \
# 0                                  @Valencamueller 😃  NiemaMovassat
# 1  @chr2stoph Klar wenn beide Seiten ohne Anwalt ...  NiemaMovassat
# 2  @Krazikrizz @kulturbolschewi Gerade am Zivilge...  NiemaMovassat
# 3  @Krazikrizz @kulturbolschewi Verwaltungsgerich...  NiemaMovassat
# 4  @Alta__Mann Ja den Eindruck habe ich am Amtsge...  NiemaMovassat
#
#      Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Niema Movassat            0              0           0
# 1  Niema Movassat            1              0           2
# 2  Niema Movassat            1              0           5
# ...

# %%
#Jan Korte 
# Creating list to append tweet data to
tweets_listLINKE4 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:jankortemdb').get_items()):
    if i>1000000:
        break
    tweets_listLINKE4.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfLINKE4 = pd.DataFrame(tweets_listLINKE4, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfLINKE4.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-01-05 16:35:32+00:00  1478767130313207810
# 1 2022-01-03 15:48:35+00:00  1478030537709211649
# 2 2022-01-03 15:48:33+00:00  1478030528976756741
# 3 2021-12-31 11:17:44+00:00  1476875214847889409
# 4 2021-12-29 08:16:38+00:00  1476104863520116741
#
#                                                 Text     Username  \
# 0  Statt die #Pflege zu unterstützen, spaltet #La...  jankortemdb
# 1  Wir finden: Die Versorgungsposten der Parlamen...  jankortemdb
# 2  Im Jahr 2019 waren 35 Parlamentarische #Staats...  jankortemdb
# 3  Gudi Rutschke euch allen. ✌️ https://t.co/FR3u...  jankortemdb
# 4  Das ist nichts anderes als das Kaufen und Schm...  jankortemdb
#
#   Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0    Jan Korte           10             23          97
# 1    Jan Korte            6             14          47
# 2    Jan Korte           19             35         171
# ...

# %%
#Dietmar Bartsch 
# Creating list to append tweet data to
tweets_listLINKE5 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:DietmarBartsch').get_items()):
    if i>1000000:
        break
    tweets_listLINKE5.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfLINKE5 = pd.DataFrame(tweets_listLINKE5, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfLINKE5.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-01-05 15:00:01+00:00  1478743092782116866
# 1 2022-01-05 13:47:50+00:00  1478724926882385926
# 2 2022-01-05 13:27:53+00:00  1478719904056500229
# 3 2022-01-05 10:24:52+00:00  1478673848740548609
# 4 2022-01-04 18:31:56+00:00  1478434036188069894
#
#                                                 Text        Username  \
# 0  Lieber @Karl_Lauterbach, statt beim #Pflegebon...  DietmarBartsch
# 1  Während @c_lindner Entlastungen für übermorgen...  DietmarBartsch
# 2  @AlexSchaumburg Wo haben Sie das gelesen? Fang...  DietmarBartsch
# 3  Herzlichen Glückwunsch, lieber @DerRostocker h...  DietmarBartsch
# 4          @afelix___ Habe ich das geschrieben? Nein  DietmarBartsch
#
#       Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Dietmar Bartsch           29             37         211
# 1  Dietmar Bartsch           28             42         180
# 2  Dietmar Bartsch            5              0          17
# ...

# %%
#Gregor Gysi 
# Creating list to append tweet data to
tweets_listLINKE6 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:GregorGysi').get_items()):
    if i>1000000:
        break
    tweets_listLINKE6.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfLINKE6 = pd.DataFrame(tweets_listLINKE6, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfLINKE6.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2021-12-31 16:00:01+00:00  1476946252487028739
# 1 2021-12-28 14:33:40+00:00  1475837359828647943
# 2 2021-12-28 14:33:40+00:00  1475837358264229894
# 3 2021-12-28 14:33:40+00:00  1475837356091625477
# 4 2021-12-24 18:00:02+00:00  1474439740929630212
#
#                                                 Text    Username Twitter_Name  \
# 0  Ich wünsche Ihnen ein tolles Jahr 2022 - mehr ...  GregorGysi  Gregor Gysi
# 1  Wissenschaftliche Aufarbeitung der Geschichte ...  GregorGysi  Gregor Gysi
# 2  Die russische Regierung sollte selbst gegen di...  GregorGysi  Gregor Gysi
# 3  Die oberstgerichtlich verfügte Auflösung von #...  GregorGysi  Gregor Gysi
# 4  Ich wünsche Ihnen ein wunderschönes #Weihnacht...  GregorGysi  Gregor Gysi
#
#    Reply_Count  Retweet_Count  Like_Count
# 0           54             58         883
# 1           30              5         218
# 2          305             17         251
# ...

# %%
#Sevim Dağdelen 
# Creating list to append tweet data to
tweets_listLINKE7 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:SevimDagdelen').get_items()):
    if i>1000000:
        break
    tweets_listLINKE7.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfLINKE7 = pd.DataFrame(tweets_listLINKE7, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfLINKE7.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-01-05 09:20:35+00:00  1478657672161468419
# 1 2021-12-31 18:39:38+00:00  1476986421634289669
# 2 2021-12-28 13:29:58+00:00  1475821328775196673
# 3 2021-12-28 09:07:30+00:00  1475755275919450113
# 4 2021-12-27 18:12:27+00:00  1475530027466903561
#
#                                                 Text       Username  \
# 0  @barbarosansalfn @Sunayyoltay @Zu_Demir @Dilan...  SevimDagdelen
# 1  Heute ist Julian #Assange seit 994 Tagen im br...  SevimDagdelen
# 2                              @DRossmanek Danke 🙏☺️  SevimDagdelen
# 3                     @manaf12hassan Immer gern. ✊✌️  SevimDagdelen
# 4  Die Kritik von Annalena #Baerbock an Waffenexp...  SevimDagdelen
#
#           Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Sevim Dağdelen, MdB            1              0           4
# 1  Sevim Dağdelen, MdB           53           1051        2665
# 2  Sevim Dağdelen, MdB            0              0           2
# ...

# %% [markdown]
# AFD

# %%
#Alice Weidel 
# Creating list to append tweet data to
tweets_listAFD1 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:Alice_Weidel').get_items()):
    if i>1000000:
        break
    tweets_listAFD1.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfAFD1 = pd.DataFrame(tweets_listAFD1, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfAFD1.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-01-05 13:07:39+00:00  1478714815862525953
# 1 2022-01-04 10:30:55+00:00  1478312984653008899
# 2 2022-01-02 16:46:26+00:00  1477682708499341312
# 3 2022-01-01 11:04:13+00:00  1477234199308419072
# 4 2021-12-28 10:39:41+00:00  1475778473251717128
#
#                                                 Text      Username  \
# 0  Chaos nicht nur beim #RKI: Einmal mehr entsteh...  Alice_Weidel
# 1  Ob es ums #Klima, die #Migration, den #Euro, d...  Alice_Weidel
# 2  #Europa setzt auf "grüne" #Atomkraft &amp; #De...  Alice_Weidel
# 3  Ich wünsche Ihrer Familie und Ihnen ein frohes...  Alice_Weidel
# 4  Die Planspiele von Herrn #Holetschek bestätige...  Alice_Weidel
#
#    Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Alice Weidel          173            450        1963
# 1  Alice Weidel          322            806        3737
# 2  Alice Weidel          259            640        2955
# ...

# %%
#Beatrix von Storch 
# Creating list to append tweet data to
tweets_listAFD2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:Beatrix_vStorch').get_items()):
    if i>1000000:
        break
    tweets_listAFD2.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfAFD2 = pd.DataFrame(tweets_listAFD2, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfAFD2.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-01-05 09:49:02+00:00  1478664828956913664
# 1 2022-01-03 15:17:18+00:00  1478022664153452546
# 2 2022-01-03 07:38:50+00:00  1477907287171903491
# 3 2022-01-01 18:50:27+00:00  1477351530156150788
# 4 2021-12-21 12:06:10+00:00  1473263523866329088
#
#                                                 Text         Username  \
# 0  Bitte aufmerksam beachten: wir unterscheiden j...  Beatrix_vStorch
# 1  Ich glaube, #Schlagstocksaskia sitzt seit gest...  Beatrix_vStorch
# 2  Ich nehme an, die sind alle geimpft und wahrsc...  Beatrix_vStorch
# 3  Ich will gleich einen Spaziergang machen. Wo m...  Beatrix_vStorch
# 4  Und was „Boostern“ heißt, ist damit auch noch ...  Beatrix_vStorch
#
#          Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Beatrix von Storch           56             79         289
# 1  Beatrix von Storch          167            321        1406
# ...

# %%
#Joana Cotar 
# Creating list to append tweet data to
tweets_listAFD3 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:JoanaCotar').get_items()):
    if i>1000000:
        break
    tweets_listAFD3.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfAFD3 = pd.DataFrame(tweets_listAFD3, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfAFD3.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-01-05 22:05:13+00:00  1478850098272550915
# 1 2022-01-05 21:29:56+00:00  1478841217983168513
# 2 2022-01-05 19:49:58+00:00  1478816061017497608
# 3 2022-01-05 19:15:00+00:00  1478807260885356551
# 4 2022-01-05 19:10:19+00:00  1478806081694572552
#
#                                                 Text    Username Twitter_Name  \
# 0  🧐🤔 Der Elefant im Raum. #Schweden https://t.co...  JoanaCotar  Joana Cotar
# 1  @Tim_Roehn @welt Wer merkt sich das eigentlich...  JoanaCotar  Joana Cotar
# 2  #Wendt: „Ein standardisiertes Einschreiten der...  JoanaCotar  Joana Cotar
# 3  @marc_gries @reitschuster Hetzen, ohne, dass d...  JoanaCotar  Joana Cotar
# 4  @marc_gries Einige Menschen brauchen anscheine...  JoanaCotar  Joana Cotar
#
#    Reply_Count  Retweet_Count  Like_Count
# 0            3             11          75
# 1            7              4          96
# 2            4             39         148
# ...

# %%
#Stephan Brandner 
# Creating list to append tweet data to
tweets_listAFD4 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:StBrandner').get_items()):
    if i>1000000:
        break
    tweets_listAFD4.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfAFD4 = pd.DataFrame(tweets_listAFD4, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfAFD4.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-01-05 18:20:03+00:00  1478793430130176004
# 1 2022-01-05 12:53:37+00:00  1478711280697552898
# 2 2022-01-05 12:51:28+00:00  1478710742992015361
# 3 2022-01-05 11:10:19+00:00  1478685287886770177
# 4 2022-01-05 10:48:21+00:00  1478679757193719809
#
#                                                 Text    Username  \
# 0          Viel CO2-Ausstoß… https://t.co/UAcnA2IM7I  StBrandner
# 1                          😉 https://t.co/I0XvlpGf5a  StBrandner
# 2  #Gürtelrose, #Biontech, #Pfizer…🤔 https://t.co...  StBrandner
# 3  „Desolat“ ist noch sehr zurückhaltend formulie...  StBrandner
# 4  Was sonst? So ist das im von #Linksextremisten...  StBrandner
#
#              Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  🇩🇪 Stephan Brandner 🇩🇪           30              7          58
# 1  🇩🇪 Stephan Brandner 🇩🇪           19              3          29
# 2  🇩🇪 Stephan Brandner 🇩🇪           39             25          93
# ...

# %%
#Tino Chrupalla 
# Creating list to append tweet data to
tweets_listAFD5 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:Tino_Chrupalla').get_items()):
    if i>1000000:
        break
    tweets_listAFD5.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfAFD5 = pd.DataFrame(tweets_listAFD5, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfAFD5.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2021-12-23 13:40:49+00:00  1474012119741960192
# 1 2021-12-19 09:27:23+00:00  1472498789122514945
# 2 2021-12-17 14:02:24+00:00  1471843224251740177
# 3 2021-12-13 16:30:19+00:00  1470430897199628298
# 4 2021-12-04 17:26:46+00:00  1467183612034433034
#
#                                                 Text        Username  \
# 0  @_FriedrichMerz will parlamentarische Zusammen...  Tino_Chrupalla
# 1  Wir wünschen Ihnen und Ihrer Familie einen bes...  Tino_Chrupalla
# 2  Mit @_FriedrichMerz gibt es keine konservative...  Tino_Chrupalla
# 3  @OlafScholz muss sich endlich klar zu Nord Str...  Tino_Chrupalla
# 4  Friedlicher Protest gegen einen #Impfzwang ist...  Tino_Chrupalla
#
#      Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Tino Chrupalla            8              3          11
# 1  Tino Chrupalla          444            332        2658
# 2  Tino Chrupalla          187            214        1011
# ...

# %%
#Götz Frömming 
# Creating list to append tweet data to
tweets_listAFD6 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:GtzFrmming').get_items()):
    if i>1000000:
        break
    tweets_listAFD6.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfAFD6 = pd.DataFrame(tweets_listAFD6, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfAFD6.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-01-04 22:16:06+00:00  1478490447236538374
# 1 2022-01-04 12:26:02+00:00  1478341953628610560
# 2 2022-01-04 07:40:05+00:00  1478269989803155456
# 3 2022-01-04 07:39:04+00:00  1478269737406799876
# 4 2022-01-03 19:12:02+00:00  1478081737188126726
#
#                                                 Text    Username  \
# 0  Bemerkenswerter Kommentar:\n„Menschen, die sic...  GtzFrmming
# 1  Die Entscheidung der EU-Kommission pro Kernene...  GtzFrmming
# 2                            https://t.co/mt0foHJd99  GtzFrmming
# 3  Mein Held des Tages: Dieser Feuerwehrmann rett...  GtzFrmming
# 4  Zahlreiche dokumentierte Fälle von #Polizeigew...  GtzFrmming
#
#          Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Götz Frömming, MdB            0              9          52
# 1  Götz Frömming, MdB            2             16          60
# 2  Götz Frömming, MdB            0              2          10
# ...

# %%
#Leif-Erik Holm 
# Creating list to append tweet data to
tweets_listAFD7 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:Leif_Erik_Holm').get_items()):
    if i>1000000:
        break
    tweets_listAFD7.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.displayname, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# Creating a dataframe from the tweets list above
tweets_dfAFD7 = pd.DataFrame(tweets_listAFD7, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Twitter_Name', 'Reply_Count', 'Retweet_Count', 'Like_Count'])

tweets_dfAFD7.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2021-12-15 09:40:48+00:00  1471052614884372480
# 1 2021-09-10 13:29:55+00:00  1436321039236182019
# 2 2021-09-02 12:28:20+00:00  1433406436600594436
# 3 2021-08-27 17:29:57+00:00  1431308014267535362
# 4 2021-08-26 13:10:41+00:00  1430880378609360905
#
#                                                 Text        Username  \
# 0  Regierungserklärung #Scholz: 90min Geschwurbel...  Leif_Erik_Holm
# 1  Das #NDR-Duell Schwesig vs. Sack ist eine Farc...  Leif_Erik_Holm
# 2  Die #Grünen-Politikerin Anne Shepley hat gefor...  Leif_Erik_Holm
# 3  Hallo Deutschland! \n\nSag mal, was ist eigent...  Leif_Erik_Holm
# 4  23 Jahre regiert die #SPD jetzt in meiner schö...  Leif_Erik_Holm
#
#      Twitter_Name  Reply_Count  Retweet_Count  Like_Count
# 0  Leif-Erik Holm           24             40         252
# 1  Leif-Erik Holm           12              8          30
# 2  Leif-Erik Holm            6             21          57
# ...

# %%
#Make files for the whole parties scraped
import pandas as pd
data_CDU = pd.concat([tweets_dfCDU1,tweets_dfCDU2,tweets_dfCDU3,tweets_dfCDU4,tweets_dfCDU5,tweets_dfCDU6,tweets_dfCDU7],ignore_index=True)
data_SPD = pd.concat([tweets_dfSPD1,tweets_dfSPD2,tweets_dfSPD3,tweets_dfSPD4,tweets_dfSPD5,tweets_dfSPD6,tweets_dfSPD7],ignore_index=True)
data_B90G = pd.concat([tweets_dfB90G1,tweets_dfB90G2,tweets_dfB90G3,tweets_dfB90G4,tweets_dfB90G5,tweets_dfB90G6,tweets_dfB90G7],ignore_index=True)
data_FDP = pd.concat([tweets_dfFDP1,tweets_dfFDP2,tweets_dfFDP3,tweets_dfFDP4,tweets_dfFDP5,tweets_dfFDP6,tweets_dfFDP7],ignore_index=True)
data_LINKE = pd.concat([tweets_dfLINKE1,tweets_dfLINKE2,tweets_dfLINKE3,tweets_dfLINKE4,tweets_dfLINKE5,tweets_dfLINKE6,tweets_dfLINKE7],ignore_index=True)
data_AFD = pd.concat([tweets_dfAFD1,tweets_dfAFD2,tweets_dfAFD3,tweets_dfAFD4,tweets_dfAFD5,tweets_dfAFD6,tweets_dfAFD7],ignore_index=True)
data_CDU.to_csv('CDU_Tweets.csv') 
data_SPD.to_csv('SPD_Tweets.csv') 
data_B90G.to_csv('B90G_Tweets.csv') 
data_FDP.to_csv('FDP_Tweets.csv') 
data_LINKE.to_csv('LINKE_Tweets.csv') 
data_AFD.to_csv('AFD_Tweets.csv') 
#Make file for the whole data
data_bundestag = pd.concat([data_CDU,data_SPD,data_B90G,data_FDP,data_LINKE,data_AFD],ignore_index=True)
display(data_bundestag)
data_bundestag.to_csv('Bundestag_Tweets.csv')
# Out:
#                         Datetime             Tweet Id  \
# 0      2021-12-24 09:06:37+00:00  1474305500472922113
# 1      2021-12-17 13:41:57+00:00  1471838074413924356
# 2      2021-12-15 12:34:54+00:00  1471096426381942791
# 3      2021-12-15 11:58:36+00:00  1471087291913449472
# 4      2021-12-15 11:58:35+00:00  1471087286301380616
# ...                          ...                  ...
# 339687 2016-09-03 03:08:23+00:00   771907664309841924
# 339688 2016-09-02 09:14:39+00:00   771637452935049216
# 339689 2016-09-02 08:42:25+00:00   771629340794556416
# 339690 2016-09-02 03:34:58+00:00   771551966128246784
# 339691 2016-09-02 03:06:41+00:00   771544847979130880
#
#                                                      Text        Username  \
# 0       Ich wünsche Ihnen ein frohes und gesegnetes We...      rbrinkhaus
# 1       Herzlichen Glückwunsch @_FriedrichMerz. Alles ...      rbrinkhaus
# 2       @dieLinke Die Rede in voller Länge gibt es in ...      rbrinkhaus
# ...

# %%
import matplotlib.pyplot as plt
data_bundestag.groupby('Twitter_Name')['Tweet Id'].nunique().sort_values().plot(kind='bar')
plt.rcParams["figure.figsize"] = (10, 20)
#plt.show()
#df.groupby('state')['name'].nunique().plot(kind='bar')

#data_bundestag['Twitter_Name'].value_counts().plot(kind='barh')
#data['title'].value_counts()[:20].plot(kind='barh')
